# %%
import numpy as np
import math
import csv
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/home/caio/remote-IPMU/Experiment/grafana_data/DT5521HEM_ Imon ch.2-data-2024-05-23 16_46_16.csv',names=["Time","IMon 2"],sep= ",",header=1)
df1 = pd.read_csv('/home/caio/remote-IPMU/Experiment/grafana_data/DT5521HEM(1)_ Imon ch.3-data-2024-05-23 16_46_24.csv',names=["Time","IMon 3"],sep= ",",header=1)



# Access data in the DataFrame using column names or indexing
print(df.columns.tolist())
print(df.iloc[0])  # Access first row
df['Time'] = pd.to_datetime(df['Time'])
df['IMon 2'] = pd.to_numeric(df['IMon 2'])*10e9

df1['Time'] = pd.to_datetime(df1['Time'])
df1['IMon 3'] = pd.to_numeric(df1['IMon 3'])*10e9
# Out:
# ['Time', 'IMon 2']
# Time      2024-05-23 15:44:55
# IMon 2                   -0.0
# Name: 0, dtype: object

# %%
df.plot(x='Time', y='IMon 2', xlabel = 'Time', ylabel = 'nA')
df1.plot(x='Time', y='IMon 3', xlabel = 'Time', ylabel = 'nA')
# Out:
# <Axes: xlabel='Time', ylabel='nA'>
